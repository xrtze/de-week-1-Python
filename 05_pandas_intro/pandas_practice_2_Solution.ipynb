# %% [markdown]
# Pandas Practice
# ====
#
#
# ![IRIS, https://github.com/simonava5/fishers-iris-data](./images/iris.png)
#
# After the notebook with a lot of new input, let's start applying it totally by yourselves.
# For this purpose we will use one of the most standard real-life datasets: Its called Iris Dataset, and is all about the plant iris. Let's learn a little bit more about the dataset by looking at it.
#
# ## Learning Objectives
#
# By the end of this notebook, you will feel more comfortable with your newly acquired knowledge, as you will see that you can
#
# - load data from csv files into DataFrames
# - access data stored in DataFrames
# - use the general functions of a DataFrame to answer questions about the data
# - create insightful plots using the Pandas function `.plot()`
# - explain what conclusions you draw from these visualizations.

# %%
# import pandas
import pandas as pd

# %%
# load the data
iris = pd.read_csv('data/iris.csv')

# %% [markdown]
# Let us first have a look at the head of the table, maybe also on the last 10 rows...

# %%
# first 5 rows
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# last 10 rows
iris.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# How many irises are in the data set?

# %%
iris.shape  # 150 irises
# Out:
# (150, 5)

# %% [markdown]
# How many different species are there?

# %%
iris.species.nunique()  # 3 different species
# Out:
# 3

# %% [markdown]
# Calculate the mean, median, mode for petal length

# %%
print('Mean: ', iris.petal_length.mean())
print('Median: ', iris.petal_length.median())
print('Mode: ', iris.petal_length.mode()[0])
# Out:
# Mean:  3.758666666666666
# Median:  4.35
# Mode:  1.5

# %% [markdown]
# What can you conclude about the distribution for petal length?

# %% [markdown]
# • Since the mean is smaller than the median we can assume that the distribution is left-skewed.

# %% [markdown]
# What is the smallest and largest value for petal lenth?

# %%
print('Largest value: ', iris.petal_length.max())
print('Smallest value: ', iris.petal_length.min())
# Out:
# Largest value:  6.9
# Smallest value:  1.0

# %% [markdown]
# Calculate the variance and standard deviation for petal length

# %%
print('Variance: ', iris.petal_length.var())
print('Standard deviation: ', iris.petal_length.std())
# Out:
# Variance:  3.113179418344519
# Standard deviation:  1.7644204199522626

# %% [markdown]
# Calculate the basic descriptive statistics for all columns of the iris data set with a single command.

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# What is the overall average for sepal length?

# %% [markdown]
# • From the table above we can see that the overall average is 5.8

# %%
# We can also calculate it 
iris.sepal_length.mean()
# Out:
# 5.843333333333334

# %% [markdown]
# Use DataFrame grouping function to determine the count by species.

# %%
iris.groupby('species').count()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %%
# We can also use the method .value_counts()
iris.species.value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: species, dtype: int64

# %% [markdown]
# Use DataFrame grouping function to determine the average length and width of sepals and pedals by species.

# %%
iris.groupby('species').mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# Add the sum of the sepal width and length as a new column to your data frame.

# %%
iris['sepal_sum'] = iris['sepal_width'] + iris['sepal_length']
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
#
#    sepal_sum
# 0        8.6
# 1        7.9

# %% [markdown]
# Visualize petal length with a histogram

# %%
iris.petal_length.plot(kind='hist');

# %% [markdown]
# Describe the distribution

# %% [markdown]
# • It seems that we have more than one distribution in the plot above.

# %% [markdown]
# Which is more informative: the summary statistics or visualizations?

# %% [markdown]
# • The plot helps to get a first impression and overview of the distribution. The summary statistics gives us more specific values.

# %% [markdown]
# Visualize petal length and width with a "scatter_matrix"

# %%
pd.plotting.scatter_matrix(iris[['petal_width', 'petal_length']]);

# %% [markdown]
# Create a new column with a rough estimate of petal area by multiplying petal length and width together.

# %%
# iris.eval('petal_area = petal_length * petal_width', inplace=True)

iris['petal_area'] = iris['petal_length'] * iris['petal_width']
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    sepal_sum  petal_area
# 0        8.6        0.28
# 1        7.9        0.28
# 2        7.9        0.26
# 3        7.7        0.30
# 4        8.6        0.28

# %% [markdown]
# Create a new dataframe with petal areas greater than $1cm^2$.

# %%
iris_petal = iris[iris.petal_area > 1]
iris_petal.head(2)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species  \
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
#
#     sepal_sum  petal_area
# 50       10.2        6.58
# 51        9.6        6.75

# %% [markdown]
# Create 3 new dataframes, one for each species. Use the entire dataset.

# %%
iris_versicolor = iris[iris.species == 'Iris-versicolor']
iris_versicolor.head(2)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species  \
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
#
#     sepal_sum  petal_area
# 50       10.2        6.58
# 51        9.6        6.75

# %%
iris_virginica = iris.query('species == "Iris-virginica"')
iris_virginica.head(2)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
#
#      sepal_sum  petal_area
# 100        9.6       15.00
# 101        8.5        9.69

# %%
iris_setosa = iris[iris.species == 'Iris-setosa']
iris_setosa.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
#
#    sepal_sum  petal_area
# 0        8.6        0.28
# 1        7.9        0.28
